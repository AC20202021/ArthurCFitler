# %%
import pandas as pd

# %%
supplierfile=r''
#To find the CapIQ supplier file name, look at bottom of computer where it says "Type here to serch." 
# After seeing the file, click "Copy full path." Then, you can paste it here. Put that entire thing in between r''
# Example: r'C:\Users\acalcagnini\Documents\Illumination NC3\avnethoneywell2.xlsx'

# %%
filterfile=r''
#Do same thing as above to find the excel filter file. This file should be the same every time you run this program.

# %%
df1 = pd.read_excel(filterfile,sheet_name='Small Electronic Component')
# Copy and paste correct sheet name at the end after it says sheet_name= ''  Do not change anything else. 
# Copy and paste the name below and put it inside the quotes. Do not include # sign or spaces. Ie: 'PRESSURIZER TANK AS'
# SHEET NAMES: 
# Small Electronic Component
# PRESSURIZER TANK AS
# Radio Frequency Filter
# Metal
# COREELECTROMAGNETIC COMPONENT
# Motorstepping
# AC Motor 
# MIXER STAGEFREQUENCY
# TRANSFORMERPOWER
# OSCILLATORCRYSTAL CONTROLLED
# SWITCHRADIO FREQUENCY --> this is for SWITCHRADIO FREQUENCY TRANSMISSION LINE
# CIRCULATORRADIO FREQUENCY
# TRANSFORMERRADIO FREQUENCY
# DIVIDERPOWERRADIO FREQUENCY
# MOTOR DRIVE ASSEMBL
# CRYSTAL UNITQUARTZ
# AMPLIFIERRADIO FREQUENCY
# REACTOR
# DEHYDRATORDESICCANTELECTRIC
# WAVEGUIDE ASSEMBLY
# AC Generator
# DC Motor
# ELECTRON TUBE
# FREQUENCY MULTIPLIER
# MICROCIRCUITDIGITAL LINEAR
# MIXER RADIO FREQUENCY
# OSCILLATOR SUBASSEMBLY
# TRANSFORMERPULSE
# ANTENNA SUBASSEMBLY

# %%
df2=df1['Industry']

# %%
print (df2)
# Out:
# 0                             Electron tubes
# 1                            Electron tubes
# 2        Motor vehicle parts and accessories
# 3       Motor vehicle parts and accessories
# 4       Motor vehicle supplies and new parts
#                         ...
# 1197                  Wood office furniture
# 1198                           Wood products
# 1199                          Wood products
# 1200                     Yarn spinning mills
# 1201                    Yarn spinning mills
# Name: Industry, Length: 1202, dtype: object

# %%
df3 = pd.read_excel(supplierfile)

# %%
df4 = pd.DataFrame(df3)

# %%
filt = ~df4['SupplierSicIndustry'].isin(df2)

# %%
df4[filt]
# Out:
#                                                    rel  \
# 0    Integrated Device Technology, Inc._Maxtek Tech...
# 1    B.O.S. Better Online Solutions Ltd._Honeywell ...
# 2    Honeywell International Inc._Diodes Incorporat...
# 3    Honeywell International Inc._Resideo Technolog...
# 4             Honeywell International Inc._Mks Corp._4
# ..                                                 ...
# 366  Intel Corporation_Giga-Byte Technology Co., Lt...
# 367         Intel Corporation_Viasystems Group, Inc._6
# 368  Intel Corporation_Advanced Connection Technolo...
# 370  Skyworks Solutions, Inc._Tong Hsing Electronic...
# 371  Skyworks Solutions, Inc._Samsung Electro-Mecha...
#
#                                    Buyer    BuyerDUNS   BuyerCID  \
# 0     Integrated Device Technology, Inc.   38142600.0   IQ518807
# 1    B.O.S. Better Online Solutions Ltd.  600285977.0   IQ395364
# 2           Honeywell International Inc.  139691877.0  IQ1340740
# 3           Honeywell International Inc.  139691877.0  IQ1340740
# 4           Honeywell International Inc.  139691877.0  IQ1340740
# ..                                   ...          ...        ...
# 366                    Intel Corporation   47897855.0    IQ21127
# 367                    Intel Corporation   47897855.0    IQ21127
# 368                    Intel Corporation   47897855.0    IQ21127
# 370             Skyworks Solutions, Inc.    1030311.0  IQ1462309
# 371             Skyworks Solutions, Inc.    1030311.0  IQ1462309
#
#                             BuyerCiqIndustry  \
# 0    Semiconductors, Semiconductor Equipment
# 1                    Technology Distributors
# 2                   Industrial Conglomerates
# 3                   Industrial Conglomerates
# 4                   Industrial Conglomerates
# ..                                       ...
# 366  Semiconductors, Semiconductor Equipment
# 367  Semiconductors, Semiconductor Equipment
# 368  Semiconductors, Semiconductor Equipment
# 370  Semiconductors, Semiconductor Equipment
# 371  Semiconductors, Semiconductor Equipment
#
#                        BuyerSicIndustry  \
# 0    Semiconductors and related devices
# 1        Electronic parts and equipment
# 2                         Conglomerates
# 3                         Conglomerates
# 4                         Conglomerates
# ..                                  ...
# 366  Semiconductors and related devices
# 367  Semiconductors and related devices
# 368  Semiconductors and related devices
# 370  Semiconductors and related devices
# 371  Semiconductors and related devices
#
#                                       BuyerFullAddress  \
# 0    6024 Silver Creek Valley Road, San Jose, Calif...
# 1    Drive-In Center Building, Industrial Zone, 20 ...
# 2    300 South Tryon Street, Charlotte, North Carol...
# 3    300 South Tryon Street, Charlotte, North Carol...
# 4    300 South Tryon Street, Charlotte, North Carol...
# ..                                                 ...
# 366  2200 Mission College Boulevard, Santa Clara, C...
# 367  2200 Mission College Boulevard, Santa Clara, C...
# 368  2200 Mission College Boulevard, Santa Clara, C...
# 370  20 Sylvan Road, Woburn, Massachusetts, 01801, ...
# 371  20 Sylvan Road, Woburn, Massachusetts, 01801, ...
#
#                         BuyerStreet      BuyerCity        BuyerState  ...  \
# 0     6024 Silver Creek Valley Road       San Jose                CA  ...
# 1          Drive-In Center Building  Rishon LeZion  Data Unavailable  ...
# 2            300 South Tryon Street      Charlotte                NC  ...
# 3            300 South Tryon Street      Charlotte                NC  ...
# 4            300 South Tryon Street      Charlotte                NC  ...
# ..                              ...            ...               ...  ...
# 366  2200 Mission College Boulevard    Santa Clara                CA  ...
# 367  2200 Mission College Boulevard    Santa Clara                CA  ...
# 368  2200 Mission College Boulevard    Santa Clara                CA  ...
# 370                  20 Sylvan Road         Woburn                MA  ...
# 371                  20 Sylvan Road         Woburn                MA  ...
#
#                                SupplierCiqIndustry  \
# 0                          Technology Distributors
# 1                         Industrial Conglomerates
# 2          Semiconductors, Semiconductor Equipment
# 3                          Technology Distributors
# 4    Printed Circuit Boards, Electronic Components
# ..                                             ...
# 366                                            NaN
# 367  Printed Circuit Boards, Electronic Components
# 368                                            NaN
# 370        Semiconductors, Semiconductor Equipment
# 371                                            NaN
#
#                        SupplierSicIndustry  \
# 0           Electronic parts and equipment
# 1                            Conglomerates
# 2       Semiconductors and related devices
# 3           Electronic parts and equipment
# 4                   Printed circuit boards
# ..                                     ...
# 366  Electronic components and accessories
# 367                 Printed circuit boards
# 368  Electronic components and accessories
# 370     Semiconductors and related devices
# 371  Electronic components and accessories
#
#                                    SupplierFullAddress  \
# 0    No.13-20, Min-Chiuan East Road, 5th Floor, Sec...
# 1    300 South Tryon Street, Charlotte, North Carol...
# 2    4949 Hedgcoxe Road, Suite 200, Plano, Texas, 7...
# 3    901 East 6th Street, Austin, Texas, 78702, Uni...
# 4    No. 120, Fu-An Street, Tu-Cheng Industrial Dis...
# ..                                                 ...
# 366  No.6, Baoqiang Road, Xindian District, New Tai...
# 367  101 South Hanley Road, Suite 1800, St. Louis, ...
# 368  No. 69, Zhongzheng East Road, 10th Floor, Sec....
# 370  83, Yenping South Road, 6th Floor, Taipei    T...
# 371  150, Maeyeong-ro, Yeongtong-gu, Suwon, Gyeongg...
#
#                      SupplierStreet     SupplierCity     SupplierState  \
# 0    No.13-20, Min-Chiuan East Road           Taipei  Data Unavailable
# 1            300 South Tryon Street        Charlotte                NC
# 2                4949 Hedgcoxe Road            Plano                TX
# 3               901 East 6th Street           Austin                TX
# 4             No. 120, Fu-An Street           Taipei  Data Unavailable
# ..                              ...              ...               ...
# 366             No.6, Baoqiang Road  New Taipei City  Data Unavailable
# 367           101 South Hanley Road        St. Louis                MO
# 368    No. 69, Zhongzheng East Road  New Taipei City  Data Unavailable
# 370          83, Yenping South Road           Taipei  Data Unavailable
# 371                150, Maeyeong-ro            Suwon  Data Unavailable
#
#     SupplierCountry SupplierLat SupplierLon Tier
# 0            Taiwan   25.068942  121.590903    2
# 1     United States   35.225608  -80.845766    3
# 2     United States   33.083473  -96.799684    4
# 3     United States   30.265172  -97.733417    4
# 4            Taiwan   24.963303  121.416443    4
# ..              ...         ...         ...  ...
# 366          Taiwan   24.978856  121.543248    6
# 367   United States   38.647836  -90.335058    6
# 368          Taiwan   25.167721  121.447301    6
# 370          Taiwan   25.043632  121.510739    6
# 371     South Korea   37.263669  127.054631    6
#
# [300 rows x 27 columns]

# %%
df4[filt].to_excel('output.xlsx')
#Change the file name to whatever you want. Keep it in the quotes. 
#To find the file. Go back to that search bar at the bottom that says "Type here to search." Search the file name. 
#Then, save it to whatever folder you want by choosing Save As.
